# %%
import numpy
import numpy as np
import sanity_funcs as sf

# %%
a=np.array([1,1,1,2,3,4])
b=np.array([2,2,2,1,4,3])
c=np.array([3,3,3,4,2,1])
d=np.array([4,4,4,3,1,2])

print(a,b,c,d)

# %%
mat=np.array([a,b,c,d])
print(mat[0:4,1:5])

# %%
sum=a+b+c+d
print(sum)

# %%
print(a)
print(sf.u1(a))
a+sf.u1(a)

# %%
a=np.array([1,1,1,2,3,4])
print(a)
print(set(a))
len(set(a))

# %%
a=1
b=2
c=3
d=1
e=1
f=5
yo = np.array([a, b, c, d, e, f])
check=set(yo)
print(check)

print(np.unique(yo,return_counts=True))

# %%
unique_vals, counts = np.unique(yo, return_counts=True)
print(f"{unique_vals},{counts}")

# %%
_, counts = np.unique(yo, return_counts=True)
print(counts.max())

# %%
a= [1,1,1,2,3,4]
b= [1,2,2,1,4,3]
c= [3,3,3,4,1,2]
d= [3,4,4,3,2,1]
import numpy
res=[3,3,3,7]

yo=numpy.array(a)+numpy.array(b)
print(yo)
print(yo[1:5]-res)

diff=yo[1:5]-res

if np.all(diff==0):
    print("dgsfsd")

# %%
import sanity_funcs as sf
def creating_rotation_list():
    """This function gives us a list of all rotations possible when the cubes are stacked!"""
    arr = []
    rotation = [sf.m0, sf.u1, sf.u2, sf.u3, sf.l1, sf.l2, sf.l3]
    for func_a in rotation:
        for func_b in rotation:
            for func_c in rotation:
                for func_d in rotation:
                    if sf.multiplicity_check([func_a, func_b, func_c, func_d],
                                             3) == 0:  #this effectively removes all same values in the list ie a,a,a,a etc
                        arr.append([func_a, func_b, func_c, func_d])

    """This should be added to ensure that the combination
    that enters also gets checked
    Have to sleep on this thought"""
    arr.append([sf.m0, sf.m0, sf.m0, sf.m0])
    return arr

rot_list=creating_rotation_list()
# for rot in rot_list:
#     print(rot)

# %%
a= [1,1,1,2,4,3]
b= [2,3,2,1,3,4]
c= [3,2,4,3,2,1]
d= [4,4,3,4,1,2]

print(sf.final_check([a,b,c,d],rot_list))
# Out:
# Traceback (most recent call last):
#   File "C:\Program Files\JetBrains\PyCharm 2025.2.2\plugins\python-ce\helpers\pydev\_pydevd_bundle\pydevd_comm.py", line 736, in make_thread_stack_str
#     append('file="%s" line="%s">' % (make_valid_xml_value(my_file), lineno))
#                                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Program Files\JetBrains\PyCharm 2025.2.2\plugins\python-ce\helpers\pydev\_pydevd_bundle\pydevd_xml.py", line 36, in make_valid_xml_value
#     return s.replace("&", "&amp;").replace('<', '&lt;').replace('>', '&gt;').replace('"', '&quot;')
#            ^^^^^^^^^
# AttributeError: 'tuple' object has no attribute 'replace'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 6
#       3 c= [3,2,4,3,2,1]
#       4 d= [4,4,3,4,1,2]
# ----> 6 print(sf.final_check([a,b,c,d],rot_list))
#
# File ~\Documents\Programming\Sanity_Files\brain\sanity_funcs.py:73, in final_check(yo, rotation_list)
#      72 def final_check(yo,rotation_list):
# ---> 73     a,b,c,d=yo
#      74     flag=0
#      75     #check=0
#      76     #check1=0
#
# File _pydevd_bundle/pydevd_cython_win32_312_64.pyx:1186, in _pydevd_bundle.pydevd_cython_win32_312_64.SafeCallWrapper.__call__()
#
# File _pydevd_bundle/pydevd_cython_win32_312_64.pyx:627, in _pydevd_bundle.pydevd_cython_win32_312_64.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle/pydevd_cython_win32_312_64.pyx:1103, in _pydevd_bundle.pydevd_cython_win32_312_64.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle/pydevd_cython_win32_312_64.pyx:1061, in _pydevd_bundle.pydevd_cython_win32_312_64.PyDBFrame.trace_dispatch()
#
# File C:\Program Files\JetBrains\PyCharm 2025.2.2\plugins\python-ce\helpers\jupyter_debug\pydev_jupyter_plugin.py:185, in stop(plugin, pydb, frame, event, args, stop_info, arg, step_cmd)
#     183     frame = suspend_jupyter(main_debugger, thread, frame, step_cmd)
#     184     if frame:
# --> 185         main_debugger.do_wait_suspend(thread, frame, event, arg)
#     186         return True
#     187 return False
#
# File C:\Program Files\JetBrains\PyCharm 2025.2.2\plugins\python-ce\helpers\pydev\pydevd.py:1196, in PyDB.do_wait_suspend(self, thread, frame, event, arg, send_suspend_message, is_unhandled_exception)
#    1193         from_this_thread.append(frame_id)
#    1195 with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, stop_reason):
# -> 1196     self._do_wait_suspend(thread, frame, event, arg, suspend_type, from_this_thread)
#
# File C:\Program Files\JetBrains\PyCharm 2025.2.2\plugins\python-ce\helpers\pydev\pydevd.py:1211, in PyDB._do_wait_suspend(self, thread, frame, event, arg, suspend_type, from_this_thread)
#    1208             self._call_mpl_hook()
#    1210         self.process_internal_commands()
# -> 1211         time.sleep(0.01)
#    1213 self.cancel_async_evaluation(get_current_thread_id(thread), str(id(frame)))
#    1215 # process any stepping instructions
#
# KeyboardInterrupt:
